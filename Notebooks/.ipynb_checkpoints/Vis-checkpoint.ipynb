# %%
import matplotlib as plt
import pandas as pd
import numpy as np

# %%
path = "/Users/tcaron/Documents/Python Scripts/KaggleS3E5/data/"

# %%
train = pd.read_csv(path+"train.csv")
test = pd.read_csv(path+"test.csv")

# %%
train
# Out:
#         Id  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0        0            8.0              0.50         0.39            2.20
# 1        1            9.3              0.30         0.73            2.30
# 2        2            7.1              0.51         0.03            2.10
# 3        3            8.1              0.87         0.22            2.60
# 4        4            8.5              0.36         0.30            2.30
# ...    ...            ...               ...          ...             ...
# 2051  2051            6.6              0.31         0.13            2.00
# 2052  2052            9.7              0.59         0.21            1.80
# 2053  2053            7.7              0.43         0.42            1.70
# 2054  2054            9.1              0.50         0.00            1.75
# 2055  2055            6.2              0.31         0.18            2.30
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %% [markdown]
# ### Analyse Univariée

# %%
train = train.drop(columns = "Id")

# %%
variablesQuant = list(train.columns)

# %%
variablesQuant.pop()
variableQual = ['quality']

# %%
dataQual = train[variableQual]
dataQuant = train[variablesQuant]

# %%
dataQuant.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    2056.000000       2056.000000  2056.000000     2056.000000
# mean        8.365175          0.527601     0.265058        2.398881
# std         1.705390          0.173164     0.188267        0.858824
# min         5.000000          0.180000     0.000000        1.200000
# 25%         7.200000          0.390000     0.090000        1.900000
# 50%         7.950000          0.520000     0.250000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     0.760000       14.000000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  2056.000000          2056.000000           2056.000000  2056.000000
# mean      0.081856            16.955982             49.236868     0.996748
# std       0.023729            10.009710             32.961141     0.001827
# ...

# %%
#fréquences et nombre de valeurs pour les variables qualitatives

for col in dataQual.columns:
    print(dataQual[col].value_counts())
    print(dataQual[col].value_counts(normalize = True))
    print("\n")
# Out:
# 5    839
# 6    778
# 7    333
# 4     55
# 8     39
# 3     12
# Name: quality, dtype: int64
# 5    0.408074
# 6    0.378405
# 7    0.161965
# 4    0.026751
# 8    0.018969
# 3    0.005837
# Name: quality, dtype: float64

# %%
#Création de boites à moustaches pour les variables quantitatives

boxplot1 = dataQuant.boxplot()

# %%
#Création d'histogramme pour les variables qualitatives

hist1 = dataQual.hist()

# %% [markdown]
# ### CONCLUSION DE L'ANALYSE UNIVARIEE
# Pas de changement sur les colonnes,
# à verifier la repartition de notre target quality

# %% [markdown]
# ### Analyse Bivariée

# %%
#Création de la matrice de corrélation 

matCorr = dataQuant.corr()
matCorr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_3927b_row0_col0, #T_3927b_row1_col1, #T_3927b_row2_col2, #T_3927b_row3_col3, #T_3927b_row4_col4, #T_3927b_row5_col5, #T_3927b_row6_col6, #T_3927b_row7_col7, #T_3927b_row8_col8, #T_3927b_row9_col9, #T_3927b_row10_col10 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_3927b_row0_col1, #T_3927b_row7_col8, #T_3927b_row9_col4 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_3927b_row0_col2 {
#   background-color: #ec8165;
#   color: #f1f1f1;
# }
# #T_3927b_row0_col3, #T_3927b_row4_col9 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_3927b_row0_col4, #T_3927b_row3_col9, #T_3927b_row9_col7 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_3927b_row0_col5, #T_3927b_row0_col8, #T_3927b_row1_col2, #T_3927b_row1_col9, #T_3927b_row2_col1, #T_3927b_row7_col10, #T_3927b_row8_col0, #T_3927b_row8_col3, #T_3927b_row8_col7, #T_3927b_row10_col4, #T_3927b_row10_col6 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# ...

# %% [markdown]
# doublon potentiel : (fixed acidity,citric acid), (free sulfur dioxide,total sulfur dioxide)
